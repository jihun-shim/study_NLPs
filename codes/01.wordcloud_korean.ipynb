# %% [markdown]
# ## 빈도수에 의한 자연어 처리

# %% [markdown]
# ### 데이터 전처리

# %%
it_sentences = [
    "인공지능 기술이 사회의 다양한 분야에 점점 더 널리 적용되고 있다.",
    "클라우드 컴퓨팅은 데이터 저장과 처리를 더욱 효율적으로 만들어 주며, 기업의 IT 인프라를 혁신하고 있다.",
    "머신러닝과 딥러닝 알고리즘은 데이터 분석과 예측 모델링에 혁명을 일으키고 있다.",
    "블록체인 기술은 금융 거래의 투명성과 보안성을 향상시키는데 기여하고 있다.",
    "사이버 보안은 디지털 시대의 중요한 이슈로 부상하고 있으며, 지속적인 관심과 개선이 요구된다.",
    # "소프트웨어 개발에서의 애자일 방법론은 빠른 시장 변화에 효과적으로 대응할 수 있게 해준다.",
    # "데이터 과학과 분석은 비즈니스 의사 결정 과정에서 중요한 역할을 하며, 기업의 경쟁력을 강화시킨다.",
    # "사물인터넷(IoT) 기술은 일상 생활을 더욱 편리하고 연결된 공간으로 변화시키고 있다.",
    # "가상현실(VR)과 증강현실(AR) 기술은 엔터테인먼트, 교육, 의료 등 다양한 분야에서 새로운 경험을 제공한다.",
    # "파이썬은 데이터 과학, 웹 개발, 자동화 스크립트 작성 등 다양한 프로그래밍 작업에 널리 사용되는 언어이다."
]

# %%
text = ''.join(it_sentences)
type(text), len(text)
# Out:
# (str, 233)

# %%
text_split = text.split(sep = ' ') # 띄어쓰기로 분리하기
type(text_split), len(text_split), text_split[:4] # 단어 출력 몇개인지
# Out:
# (list, 51, ['인공지능', '기술이', '사회의', '다양한'])

# %% [markdown]
# ### 단어(명사, 품사, 대명사 등등) 사전

# %%
# 단어마다 빈도수
from collections import Counter
counter_text_split = Counter(text_split) # 중복된 단어 출력시 사용
type(counter_text_split), counter_text_split.most_common()[:10] # get list ,list 얻기
# word cloud 에서 불용어 처리 필요 (and, is, of, the 등)
# Out:
# (collections.Counter,
#  [('데이터', 2),
#   ('인공지능', 1),
#   ('기술이', 1),
#   ('사회의', 1),
#   ('다양한', 1),
#   ('분야에', 1),
#   ('점점', 1),
#   ('더', 1),
#   ('널리', 1),
#   ('적용되고', 1)])

# %% [markdown]
# ### word cloud

# %%
## 한글 처리
# !apt-get -y  install fonts-nanum 1. 한글 폰트 설치 확인
# !ls /usr/share/fonts/truetype/nanum/ 2. 설치된 폰트 확인
# !ls /usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf
# Out:
# /usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf

# %%
from wordcloud import WordCloud # is, the, an 등등 없애는 모듈 즉 불용어 없애는 모듈

# %%
wordCloud = WordCloud(background_color='white'
                      , font_path='/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf')

'''
3. WordCloud에 한글 폰트 설정
WordCloud를 생성할 때 한글 폰트를 지정해야 한글이 제대로 출력됩니다.
font_path에 한글 폰트 파일 경로를 전달합니다.
여기서는 /usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf를 사용합니다.
background_color='white': WordCloud의 배경색을 흰색으로 설정합니다.
'''

# %%
wordCloud.generate_from_text(text)

# %%
wordCloud.words_ # 확률로 담아 보여줌
# Out:
# {'있다': 1.0,
#  '데이터': 0.5,
#  '인공지능': 0.25,
#  '기술이': 0.25,
#  '사회의': 0.25,
#  '다양한': 0.25,
#  '분야에': 0.25,
#  '점점': 0.25,
#  '더': 0.25,
#  '널리': 0.25,
#  '적용되고': 0.25,
#  '클라우드': 0.25,
#  '컴퓨팅은': 0.25,
#  '저장과': 0.25,
#  '처리를': 0.25,
#  '더욱': 0.25,
#  '효율적으로': 0.25,
#  '만들어': 0.25,
#  '주며': 0.25,
#  '기업의': 0.25,
#  '인프라를': 0.25,
#  '혁신하고': 0.25,
#  '머신러닝과': 0.25,
#  '딥러닝': 0.25,
#  '알고리즘은': 0.25,
#  '분석과': 0.25,
#  '예측': 0.25,
#  '모델링에': 0.25,
#  '혁명을': 0.25,
#  '일으키고': 0.25,
#  '블록체인': 0.25,
#  '기술은': 0.25,
#  '금융': 0.25,
#  '거래의': 0.25,
#  '투명성과': 0.25,
#  '보안성을': 0.25,
#  '향상시키는데': 0.25,
#  '기여하고': 0.25,
#  '사이버': 0.25,
#  '보안은': 0.25,
#  '디지털': 0.25,
#  '시대의': 0.25,
#  '중요한': 0.25,
#  '이슈로': 0.25,
#  '부상하고': 0.25,
#  '있으며': 0.25,
#  '지속적인': 0.25,
#  '관심과': 0.25,
#  '개선이': 0.25,
#  '요구된다': 0.25}

# %%
import matplotlib.pyplot as plt
plt.imshow(wordCloud)
plt.axis('off') # 그래프 좌표 없앰
plt.show()
